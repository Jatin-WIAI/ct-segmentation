# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import nibabel as nib

from glob import glob

import matplotlib.pyplot as plt

# %%
ROOT_DIR = '/scratche/data/abdomenCT-1k/Cases'

# %%
ROOT_DIR = '/scratche/data/abdomenCT-1k/'
all_images = glob(ROOT_DIR+'Cases/*.nii.gz')
all_masks = glob(ROOT_DIR+'Masks/*.nii.gz')

# %%
ctscan = nib.load(all_images[0]).get_fdata()
mask = nib.load(all_masks[0]).get_fdata()

# %%
plt.imshow(ctscan[:, :, 142], cmap='gray')

# %%
plt.imshow(mask[:, :, 142], cmap='gray')
